# %%
import numpy as np
import pandas as pd

# %%
product_df = pd.DataFrame(
    {'product': ['dairy', 'dairy', 'dairy', 'vegetables', 'fruits'],
     'price': [2.56, 2.56, 4.55, 2.74, 5.44]}
)
product_df
# Out:
#       product  price
# 0       dairy   2.56
# 1       dairy   2.56
# 2       dairy   4.55
# 3  vegetables   2.74
# 4      fruits   5.44

# %%
product_df.shape
# Out:
# (5, 2)

# %%
product_df.nunique()
# Out:
# product    3
# price      4
# dtype: int64

# %%
product_df.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
product_df.duplicated(subset='product')
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
product_df.duplicated(subset='price', keep='last')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
product_df.drop_duplicates()
# Out:
#       product  price
# 0       dairy   2.56
# 2       dairy   4.55
# 3  vegetables   2.74
# 4      fruits   5.44

# %%
product_df.drop_duplicates(subset='price')
# Out:
#       product  price
# 0       dairy   2.56
# 2       dairy   4.55
# 3  vegetables   2.74
# 4      fruits   5.44

# %%
product_df.drop_duplicates(subset='product', keep='last', ignore_index=True)
# Out:
#       product  price
# 0       dairy   4.55
# 1  vegetables   2.74
# 2      fruits   5.44

# %%
oil = pd.read_csv('./assets/oil.csv')
oil.columns = ['date', 'price']
oil['euro_price'] = oil['price'] * 1.1
oil.tail()
# Out:
#             date  price  euro_price
# 1213  2017-08-25  47.65      52.415
# 1214  2017-08-28  46.40      51.040
# 1215  2017-08-29  46.46      51.106
# 1216  2017-08-30  45.96      50.556
# 1217  2017-08-31  47.26      51.986

# %%
oil = pd.concat([oil, oil.iloc[[-1]]])
oil.tail()
# Out:
#             date  price  euro_price
# 1214  2017-08-28  46.40      51.040
# 1215  2017-08-29  46.46      51.106
# 1216  2017-08-30  45.96      50.556
# 1217  2017-08-31  47.26      51.986
# 1217  2017-08-31  47.26      51.986

# %%
oil.shape
# Out:
# (1219, 3)

# %%
oil.nunique()
# Out:
# date          1218
# price          998
# euro_price     998
# dtype: int64

# %%
oil.duplicated().sum()
# Out:
# np.int64(1)

# %%
oil.duplicated(subset='price').sum()
# Out:
# np.int64(220)

# %%
oil.drop_duplicates()
# Out:
#             date  price  euro_price
# 0     2013-01-01    NaN         NaN
# 1     2013-01-02  93.14     102.454
# 2     2013-01-03  92.97     102.267
# 3     2013-01-04  93.12     102.432
# 4     2013-01-07  93.20     102.520
# ...          ...    ...         ...
# 1213  2017-08-25  47.65      52.415
# 1214  2017-08-28  46.40      51.040
# 1215  2017-08-29  46.46      51.106
# 1216  2017-08-30  45.96      50.556
# 1217  2017-08-31  47.26      51.986
#
# [1218 rows x 3 columns]

# %%
oil.drop_duplicates(keep='last')
# Out:
#             date  price  euro_price
# 0     2013-01-01    NaN         NaN
# 1     2013-01-02  93.14     102.454
# 2     2013-01-03  92.97     102.267
# 3     2013-01-04  93.12     102.432
# 4     2013-01-07  93.20     102.520
# ...          ...    ...         ...
# 1213  2017-08-25  47.65      52.415
# 1214  2017-08-28  46.40      51.040
# 1215  2017-08-29  46.46      51.106
# 1216  2017-08-30  45.96      50.556
# 1217  2017-08-31  47.26      51.986
#
# [1218 rows x 3 columns]

# %%
oil.drop_duplicates(keep='last', ignore_index=True)
# Out:
#             date  price  euro_price
# 0     2013-01-01    NaN         NaN
# 1     2013-01-02  93.14     102.454
# 2     2013-01-03  92.97     102.267
# 3     2013-01-04  93.12     102.432
# 4     2013-01-07  93.20     102.520
# ...          ...    ...         ...
# 1213  2017-08-25  47.65      52.415
# 1214  2017-08-28  46.40      51.040
# 1215  2017-08-29  46.46      51.106
# 1216  2017-08-30  45.96      50.556
# 1217  2017-08-31  47.26      51.986
#
# [1218 rows x 3 columns]

# %%
oil.drop_duplicates(subset=['price'], keep='first', ignore_index=True)
# Out:
#            date  price  euro_price
# 0    2013-01-01    NaN         NaN
# 1    2013-01-02  93.14     102.454
# 2    2013-01-03  92.97     102.267
# 3    2013-01-04  93.12     102.432
# 4    2013-01-07  93.20     102.520
# ..          ...    ...         ...
# 994  2017-08-15  47.57      52.327
# 995  2017-08-18  48.59      53.449
# 996  2017-08-21  47.39      52.129
# 997  2017-08-30  45.96      50.556
# 998  2017-08-31  47.26      51.986
#
# [999 rows x 3 columns]
