# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Assignment 1: DataFrame Basics
#
# Hi there!
#
# Can you read in the transactions dataset and report on:
#
# * The number of rows and columns
# * The names of the columns
# * The datatypes of each column

# %%
# A common practice is to create a path variable to pass to read_csv
path = "./assets/transactions.csv"
transactions = pd.read_csv(path)
transactions
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
transactions.shape
# Out:
# (83488, 3)

# %%
transactions.columns
# Out:
# Index(['date', 'store_nbr', 'transactions'], dtype='str')

# %%
transactions.dtypes
# Out:
# date              str
# store_nbr       int64
# transactions    int64
# dtype: object

# %% [markdown]
# # Assignment 2: Exploring DataFrames
#
# Hello!
#
# * Can you quickly inspect the first 5 rows of the transactions data?
#
# * Then, dive a bit more deeply into the data and check if there are any missing values.
# * What about the number of unique dates? I want to make sure we didn’t leave any out.
# * Finally, can you report the mean, median, min and max of “transactions”?  I want to check for any anomalies in our data.

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
transactions.isna().sum()
# Out:
# date            0
# store_nbr       0
# transactions    0
# dtype: int64

# %%
transactions.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  str
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: int64(2), str(1)
# memory usage: 2.7 MB

# %%
transactions.describe(include='all')
# Out:
#               date     store_nbr  transactions
# count        83488  83488.000000  83488.000000
# unique        1682           NaN           NaN
# top     2017-04-20           NaN           NaN
# freq            54           NaN           NaN
# mean           NaN     26.939237   1694.602158
# std            NaN     15.608204    963.286644
# min            NaN      1.000000      5.000000
# 25%            NaN     13.000000   1046.000000
# 50%            NaN     27.000000   1393.000000
# 75%            NaN     40.000000   2079.000000
# max            NaN     54.000000   8359.000000

# %% [markdown]
# # Exercise 3 - Accessing DataFrames
#
# Hi, starting to dive deeper into this data.
#
# I noticed that the first row is the only one from 2013-01-01.
#
# * Can you get me a copy of the DataFrame that excludes that row, and only includes “store_nbr” and “transactions”?
# * Also, can you report the number of unique store numbers?
# * Finally, return the total number of transactions in millions

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
transactions.loc[1:, ['store_nbr', 'transactions']]
# Out:
#        store_nbr  transactions
# 1              1          2111
# 2              2          2358
# 3              3          3487
# 4              4          1922
# 5              5          1903
# ...          ...           ...
# 83483         50          2804
# 83484         51          1573
# 83485         52          2255
# 83486         53           932
# 83487         54           802
#
# [83487 rows x 2 columns]

# %%
transactions.loc[:, 'store_nbr'].nunique()
# Out:
# 54

# %%
transactions['transactions'].sum() / 1000000
# Out:
# np.float64(141.478945)

# %% [markdown]
# # Assignment 4: Dropping Data and Duplicates
#
# Hi there!
#
# Can you:
#
# 1. Drop the first row of data? We want it permanently removed.
# 2. Drop the date column but not in place
# 3. Return a dataframe that only includes the last row for each of the stores.
#
# Thanks!

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
transactions.drop(0, axis=0, inplace=True)
transactions.head()
# Out:
#          date  store_nbr  transactions
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922
# 5  2013-01-02          5          1903

# %%
transactions.drop('date', axis=1)
# Out:
#        store_nbr  transactions
# 1              1          2111
# 2              2          2358
# 3              3          3487
# 4              4          1922
# 5              5          1903
# ...          ...           ...
# 83483         50          2804
# 83484         51          1573
# 83485         52          2255
# 83486         53           932
# 83487         54           802
#
# [83487 rows x 2 columns]

# %%
transactions.drop_duplicates(subset='store_nbr', keep='last', ignore_index=True)
# Out:
#           date  store_nbr  transactions
# 0   2017-08-15          1          1693
# 1   2017-08-15          2          1737
# 2   2017-08-15          3          2956
# 3   2017-08-15          4          1283
# 4   2017-08-15          5          1310
# 5   2017-08-15          6          1589
# 6   2017-08-15          7          1780
# 7   2017-08-15          8          2621
# 8   2017-08-15          9          2155
# 9   2017-08-15         10          1010
# 10  2017-08-15         11          2360
# 11  2017-08-15         12          1096
# 12  2017-08-15         13           842
# 13  2017-08-15         14          1241
# 14  2017-08-15         15          1320
# 15  2017-08-15         16           742
# 16  2017-08-15         17          1504
# 17  2017-08-15         18          1343
# 18  2017-08-15         19          1158
# 19  2017-08-15         20          1516
# 20  2017-08-15         21          1059
# 21  2017-08-15         22           766
# 22  2017-08-15         23           946
# 23  2017-08-15         24          2138
# 24  2017-08-15         25           849
# 25  2017-08-15         26           534
# 26  2017-08-15         27          1543
# 27  2017-08-15         28          1343
# 28  2017-08-15         29          1302
# 29  2017-08-15         30           825
# 30  2017-08-15         31          1360
# 31  2017-08-15         32           615
# 32  2017-08-15         33           919
# 33  2017-08-15         34          2007
# 34  2017-08-15         35           612
# 35  2017-08-15         36          1192
# 36  2017-08-15         37          1373
# 37  2017-08-15         38          1445
# 38  2017-08-15         39          1425
# 39  2017-08-15         40          1392
# 40  2017-08-15         41          1003
# 41  2017-08-15         42           995
# 42  2017-08-15         43          1482
# 43  2017-08-15         44          3815
# 44  2017-08-15         45          3685
# 45  2017-08-15         46          3197
# 46  2017-08-15         47          3581
# 47  2017-08-15         48          2722
# 48  2017-08-15         49          2814
# 49  2017-08-15         50          2804
# 50  2017-08-15         51          1573
# 51  2017-08-15         52          2255
# 52  2017-08-15         53           932
# 53  2017-08-15         54           802

# %% [markdown]
# # Assignment 5: Missing Data
#
# Hello,
#
# Can you tell if any dates or prices are missing in the oil dataset?
#
# Then compare the mean of the oil series when filling in with mean vs. filling in with 0.
#
# Thanks!

# %%
oil = pd.read_csv("./assets/oil.csv")
oil.columns = ['date', 'price']
oil.head()
# Out:
#          date  price
# 0  2013-01-01    NaN
# 1  2013-01-02  93.14
# 2  2013-01-03  92.97
# 3  2013-01-04  93.12
# 4  2013-01-07  93.20

# %%
oil.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1218 non-null   str
#  1   price   1175 non-null   float64
# dtypes: float64(1), str(1)
# memory usage: 31.1 KB

# %%
oil.isna().sum()
# Out:
# date      0
# price    43
# dtype: int64

# %%
oil['price'].mean()
# Out:
# np.float64(67.71436595744682)

# %%
oil_filled_with_mean = oil.fillna({'price': oil['price'].mean()})
oil_filled_with_mean.loc[:,'price'].mean()
# Out:
# np.float64(67.71436595744682)

# %%
oil_filled_with_zero = oil.fillna({'price': 0})
oil_filled_with_zero['price'].mean()
# Out:
# np.float64(65.32379310344828)

# %% [markdown]
# # Assignment 6: Filtering DataFrames
#
# I need some quick research on store 25:
#
# * First, calculate the percentage of times ALL stores had more than 2000 transactions
# * Then, calculate the percentage of times store 25 had more than 2000 transactions, and calculate the sum of transactions on these days
# * Finally, sum the transactions for stores 25 and 31, that occurred in May or June, and had less than 2000 transactions

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922
# 5  2013-01-02          5          1903

# %%
(transactions['transactions'] > 2000).mean()
# Out:
# np.float64(0.266808006036868)

# %%
(transactions.query("store_nbr == 25")['transactions'] > 2000).mean()
# Out:
# np.float64(0.03469640644361834)

# %%
transactions.query('store_nbr == 25 and transactions > 2000')['transactions'].sum()
# Out:
# np.int64(144903)

# %%
transactions.query("store_nbr in [25, 31] and date.str[6] in ['5', '6'] and transactions < 2000").transactions.sum()
# Out:
# np.int64(644910)

# %% [markdown]
# # Assignment 7: Sorting DataFrames
#
# Hi there,
# * Can you get me a dataset that includes the 5 days with the highest transactions counts? Any similarities between them?
# * Then, can you get me a dataset sorted by date from earliest to most recent, but with the highest transactions first and the lowest transactions last for each day?
# * Finally, sort the columns in reverse alphabetical order.
#
# Thanks!

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922
# 5  2013-01-02          5          1903

# %%
transactions.sort_values('transactions', ascending=False).head(5)
# Out:
#              date  store_nbr  transactions
# 52011  2015-12-23         44          8359
# 71010  2016-12-23         44          8307
# 16570  2013-12-23         44          8256
# 33700  2014-12-23         44          8120
# 16572  2013-12-23         46          8001

# %%
transactions.sort_values(['date', 'transactions'], ascending=[True, False])
# Out:
#              date  store_nbr  transactions
# 40     2013-01-02         46          4886
# 38     2013-01-02         44          4821
# 39     2013-01-02         45          4208
# 41     2013-01-02         47          4161
# 11     2013-01-02         11          3547
# ...           ...        ...           ...
# 83455  2017-08-15         22           766
# 83449  2017-08-15         16           742
# 83465  2017-08-15         32           615
# 83468  2017-08-15         35           612
# 83459  2017-08-15         26           534
#
# [83487 rows x 3 columns]

# %%
transactions.sort_index(axis=1, ascending=False)
# Out:
#        transactions  store_nbr        date
# 1              2111          1  2013-01-02
# 2              2358          2  2013-01-02
# 3              3487          3  2013-01-02
# 4              1922          4  2013-01-02
# 5              1903          5  2013-01-02
# ...             ...        ...         ...
# 83483          2804         50  2017-08-15
# 83484          1573         51  2017-08-15
# 83485          2255         52  2017-08-15
# 83486           932         53  2017-08-15
# 83487           802         54  2017-08-15
#
# [83487 rows x 3 columns]

# %% [markdown]
# # Assignment 8: Modifying Columns
#
# Just some quick work, but can you send me the transaction data with the columns renamed?
#
# * Rename `transactions` to `transaction_count` and `store_nbr` to `store_number`.
# * Reorder the columns so date is first, then store number, then transaction count.
#
# Thanks!

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922
# 5  2013-01-02          5          1903

# %%
(transactions
    .rename(columns={'transactions': 'transaction_count', 'store_nbr': 'store_number'})
)
# Out:
#              date  store_number  transaction_count
# 1      2013-01-02             1               2111
# 2      2013-01-02             2               2358
# 3      2013-01-02             3               3487
# 4      2013-01-02             4               1922
# 5      2013-01-02             5               1903
# ...           ...           ...                ...
# 83483  2017-08-15            50               2804
# 83484  2017-08-15            51               1573
# 83485  2017-08-15            52               2255
# 83486  2017-08-15            53                932
# 83487  2017-08-15            54                802
#
# [83487 rows x 3 columns]

# %%
(transactions
    .rename(columns={'transactions': 'transaction_count', 'store_nbr': 'store_number'})
    .reindex(labels=['date', 'store_number', 'transaction_count'], axis=1)
)
# Out:
#              date  store_number  transaction_count
# 1      2013-01-02             1               2111
# 2      2013-01-02             2               2358
# 3      2013-01-02             3               3487
# 4      2013-01-02             4               1922
# 5      2013-01-02             5               1903
# ...           ...           ...                ...
# 83483  2017-08-15            50               2804
# 83484  2017-08-15            51               1573
# 83485  2017-08-15            52               2255
# 83486  2017-08-15            53                932
# 83487  2017-08-15            54                802
#
# [83487 rows x 3 columns]

# %% [markdown]
# # Assignment 9: Column Creation
#
# Just some quick work, but can you send me the transaction data with the columns renamed?
#
# * Create a `pct_to_target` column that divides transactions by 2500.
# * Then, create a `met_target` column that returns True if `pct_to_target` is greater than or equal to 1.
# * Next, create a `bonus_payable` column that equals 100 if `met_target` is True, and 0 if not. Then sum the bonus payable column.
# * Finally, create columns for month and day of week as integers. There is some helper code for these dateparts below.
#
#
#
# Thanks!

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922
# 5  2013-01-02          5          1903

# %%
transactions['pct_to_target'] = transactions.loc[:, 'transactions'] / 2500
transactions.head()
# Out:
#          date  store_nbr  transactions  pct_to_target
# 1  2013-01-02          1          2111         0.8444
# 2  2013-01-02          2          2358         0.9432
# 3  2013-01-02          3          3487         1.3948
# 4  2013-01-02          4          1922         0.7688
# 5  2013-01-02          5          1903         0.7612

# %%
transactions['met_target'] = transactions.loc[:, 'pct_to_target'] >= 1
transactions.head()
# Out:
#          date  store_nbr  transactions  pct_to_target  met_target
# 1  2013-01-02          1          2111         0.8444       False
# 2  2013-01-02          2          2358         0.9432       False
# 3  2013-01-02          3          3487         1.3948        True
# 4  2013-01-02          4          1922         0.7688       False
# 5  2013-01-02          5          1903         0.7612       False

# %%
transactions['bonus_payable'] = 100 * transactions.loc[:, 'met_target']
transactions.head()
# Out:
#          date  store_nbr  transactions  pct_to_target  met_target  \
# 1  2013-01-02          1          2111         0.8444       False
# 2  2013-01-02          2          2358         0.9432       False
# 3  2013-01-02          3          3487         1.3948        True
# 4  2013-01-02          4          1922         0.7688       False
# 5  2013-01-02          5          1903         0.7612       False
#
#    bonus_payable
# 1              0
# 2              0
# 3            100
# 4              0
# 5              0

# %%
transactions.loc[:,'bonus_payable'].sum()
# Out:
# np.int64(1448300)

# %%
transactions['date'] = pd.to_datetime(transactions.loc[:, 'date'])
transactions['month'] = transactions.loc[:, 'date'].dt.month
transactions['day'] = transactions.loc[:, 'date'].dt.day
transactions.dtypes
# Out:
# date             datetime64[us]
# store_nbr                 int64
# transactions              int64
# pct_to_target           float64
# met_target                 bool
# bonus_payable             int64
# month                     int32
# day                       int32
# dtype: object

# %%
transactions
# Out:
#             date  store_nbr  transactions  pct_to_target  met_target  \
# 1     2013-01-02          1          2111         0.8444       False
# 2     2013-01-02          2          2358         0.9432       False
# 3     2013-01-02          3          3487         1.3948        True
# 4     2013-01-02          4          1922         0.7688       False
# 5     2013-01-02          5          1903         0.7612       False
# ...          ...        ...           ...            ...         ...
# 83483 2017-08-15         50          2804         1.1216        True
# 83484 2017-08-15         51          1573         0.6292       False
# 83485 2017-08-15         52          2255         0.9020       False
# 83486 2017-08-15         53           932         0.3728       False
# 83487 2017-08-15         54           802         0.3208       False
#
#        bonus_payable  month  day
# 1                  0      1    2
# 2                  0      1    2
# 3                100      1    2
# 4                  0      1    2
# 5                  0      1    2
# ...              ...    ...  ...
# 83483            100      8   15
# 83484              0      8   15
# 83485              0      8   15
# 83486              0      8   15
# 83487              0      8   15
#
# [83487 rows x 8 columns]

# %% [markdown]
# # Assignment 10: np.select
#
# Hi there! I need a few columns created.
#
# 1. Create a ‘seasonal_bonus’ column that applies to these dates:
#     * All days in December (month = 12)
#     * Sundays (day_of_week = 6) in May (month = 5)
#     * Mondays (day_of_week = 0) in July (month = 7)
# 2. Call the December bonus ‘Holiday Bonus’, the May bonus ‘Corporate Month’, and the July bonus ‘Summer Special’. If no bonus applies, the column should display ‘None’.
# 3. Finally, calculate the total bonus owed at $100 per day.
#
# Thanks!

# %%
transactions.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 83487 entries, 1 to 83487
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           83487 non-null  datetime64[us]
#  1   store_nbr      83487 non-null  int64
#  2   transactions   83487 non-null  int64
#  3   pct_to_target  83487 non-null  float64
#  4   met_target     83487 non-null  bool
#  5   bonus_payable  83487 non-null  int64
#  6   month          83487 non-null  int32
#  7   day            83487 non-null  int32
# dtypes: bool(1), datetime64[us](1), float64(1), int32(2), int64(3)
# memory usage: 3.9 MB

# %%
conditions = [
    (transactions['month'] == 12),
    (transactions['date'].dt.day_of_week == 6) & (transactions['date'].dt.month == 5),
    (transactions['date'].dt.day_of_week == 0) & (transactions['date'].dt.month == 7)
]
choises = ['Holiday Bonus', 'Corporate Month', 'Summer Special']  
transactions['seasonal_bonus'] = np.select(conditions, choises, default='None')
transactions['seasonal_bonus'].value_counts()
# Out:
# seasonal_bonus
# None               75258
# Holiday Bonus       6028
# Summer Special      1103
# Corporate Month     1098
# Name: count, dtype: int64

# %%
transactions['seasonal_bonus'].value_counts().iloc[1:].sum() * 100
# Out:
# np.int64(822900)

# %% [markdown]
# # Assignment 11: Assign
#
# * Drop the columns that have been created so far (keep only date, store_number, and transaction count), and recreate them using the assign method.
# * Then sum the seasonal bonus owed once again to make sure the numbers are correct.

# %%
transactions.head()
# Out:
#         date  store_nbr  transactions  pct_to_target  met_target  \
# 1 2013-01-02          1          2111         0.8444       False
# 2 2013-01-02          2          2358         0.9432       False
# 3 2013-01-02          3          3487         1.3948        True
# 4 2013-01-02          4          1922         0.7688       False
# 5 2013-01-02          5          1903         0.7612       False
#
#    bonus_payable  month  day seasonal_bonus
# 1              0      1    2           None
# 2              0      1    2           None
# 3            100      1    2           None
# 4              0      1    2           None
# 5              0      1    2           None

# %%
# Drop columns we created in prior exercises
transactions.drop(['pct_to_target', 'met_target', 'bonus_payable', 'month', 'day', 'seasonal_bonus'], inplace=True, axis=1)
transactions.head()
# Out:
#         date  store_nbr  transactions
# 1 2013-01-02          1          2111
# 2 2013-01-02          2          2358
# 3 2013-01-02          3          3487
# 4 2013-01-02          4          1922
# 5 2013-01-02          5          1903

# %%
# Create same columns with assign
transactions = transactions.assign(
    pct_to_target = transactions.loc[:, 'transactions'] / 2500,
    met_target = lambda x: x.loc[:, 'pct_to_target'] >= 1,
    bonus_payable = lambda x: x.loc[:, 'met_target'] * 100,
    month = transactions['date'].dt.month,
    day_of_week = transactions['date'].dt.day_of_week,
    seasonal_bonus = np.select(conditions, choises, 'None')
)
transactions
# Out:
#             date  store_nbr  transactions  pct_to_target  met_target  \
# 1     2013-01-02          1          2111         0.8444       False
# 2     2013-01-02          2          2358         0.9432       False
# 3     2013-01-02          3          3487         1.3948        True
# 4     2013-01-02          4          1922         0.7688       False
# 5     2013-01-02          5          1903         0.7612       False
# ...          ...        ...           ...            ...         ...
# 83483 2017-08-15         50          2804         1.1216        True
# 83484 2017-08-15         51          1573         0.6292       False
# 83485 2017-08-15         52          2255         0.9020       False
# 83486 2017-08-15         53           932         0.3728       False
# 83487 2017-08-15         54           802         0.3208       False
#
#        bonus_payable  month  day_of_week seasonal_bonus
# 1                  0      1            2           None
# 2                  0      1            2           None
# 3                100      1            2           None
# 4                  0      1            2           None
# 5                  0      1            2           None
# ...              ...    ...          ...            ...
# 83483            100      8            1           None
# 83484              0      8            1           None
# 83485              0      8            1           None
# 83486              0      8            1           None
# 83487              0      8            1           None
#
# [83487 rows x 9 columns]

# %%
transactions['seasonal_bonus'].value_counts().iloc[1:].sum() * 100
# Out:
# np.int64(822900)

# %% [markdown]
# # Assignment 12: Memory Optimization
#
# Reduce the memory usage of the transactions DataFrame to below 5MB.

# %%
transactions.head()
# Out:
#         date  store_nbr  transactions  pct_to_target  met_target  \
# 1 2013-01-02          1          2111         0.8444       False
# 2 2013-01-02          2          2358         0.9432       False
# 3 2013-01-02          3          3487         1.3948        True
# 4 2013-01-02          4          1922         0.7688       False
# 5 2013-01-02          5          1903         0.7612       False
#
#    bonus_payable  month  day_of_week seasonal_bonus
# 1              0      1            2           None
# 2              0      1            2           None
# 3            100      1            2           None
# 4              0      1            2           None
# 5              0      1            2           None

# %%
transactions.info(memory_usage="deep")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 83487 entries, 1 to 83487
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            83487 non-null  datetime64[us]
#  1   store_nbr       83487 non-null  int64
#  2   transactions    83487 non-null  int64
#  3   pct_to_target   83487 non-null  float64
#  4   met_target      83487 non-null  bool
#  5   bonus_payable   83487 non-null  int64
#  6   month           83487 non-null  int32
#  7   day_of_week     83487 non-null  int32
#  8   seasonal_bonus  83487 non-null  str
# dtypes: bool(1), datetime64[us](1), float64(1), int32(2), int64(3), str(1)
# memory usage: 4.9 MB

# %%
transactions.describe()
# Out:
#                              date     store_nbr  transactions  pct_to_target  \
# count                       83487  83487.000000  83487.000000   83487.000000
# mean   2015-05-20 16:22:40.882532     26.939260   1694.613233       0.677845
# min           2013-01-02 00:00:00      1.000000      5.000000       0.002000
# 25%           2014-03-27 00:00:00     13.000000   1046.000000       0.418400
# 50%           2015-06-08 00:00:00     27.000000   1393.000000       0.557200
# 75%           2016-07-14 12:00:00     40.000000   2079.000000       0.831600
# max           2017-08-15 00:00:00     54.000000   8359.000000       3.343600
# std                           NaN     15.608296    963.287098       0.385315
#
#        bonus_payable         month   day_of_week
# count   83487.000000  83487.000000  83487.000000
# mean       17.347611      6.240864      2.995916
# min         0.000000      1.000000      0.000000
# 25%         0.000000      3.000000      1.000000
# 50%         0.000000      6.000000      3.000000
# 75%         0.000000      9.000000      5.000000
# max       100.000000     12.000000      6.000000
# std        37.866062      3.374460      2.000143

# %%
transactions.memory_usage(deep=True)
# Out:
# Index                 132
# date               667896
# store_nbr          667896
# transactions       667896
# pct_to_target      667896
# met_target          83487
# bonus_payable      667896
# month              333948
# day_of_week        333948
# seasonal_bonus    1079204
# dtype: int64

# %%
transactions = transactions.astype({
    'store_nbr': 'int16',
    'seasonal_bonus': 'category',
    'transactions': 'int32',
    'bonus_payable': 'int16',
    'month': 'int8',
    'day_of_week': 'int8',
    'pct_to_target': 'float16'
    
})
transactions.info(memory_usage='deep')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 83487 entries, 1 to 83487
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            83487 non-null  datetime64[us]
#  1   store_nbr       83487 non-null  int16
#  2   transactions    83487 non-null  int32
#  3   pct_to_target   83487 non-null  float16
#  4   met_target      83487 non-null  bool
#  5   bonus_payable   83487 non-null  int16
#  6   month           83487 non-null  int8
#  7   day_of_week     83487 non-null  int8
#  8   seasonal_bonus  83487 non-null  category
# dtypes: bool(1), category(1), datetime64[us](1), float16(1), int16(2), int32(1), int8(2)
# memory usage: 1.8 MB
