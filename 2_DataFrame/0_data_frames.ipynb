# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(
    {
        'id': ['pouria7gh', 'mohamad_99', 'fatima111', 'catty_love'],
        'name': ['pouria', 'mohamad', 'fatima', 'catty'],
        'age': [21, 30, 19, 6]
    }
)
df
# Out:
#            id     name  age
# 0   pouria7gh   pouria   21
# 1  mohamad_99  mohamad   30
# 2   fatima111   fatima   19
# 3  catty_love    catty    6

# %%
df.shape
# Out:
# (4, 3)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns
# Out:
# Index(['id', 'name', 'age'], dtype='str')

# %%
df.dtypes
# Out:
# id        str
# name      str
# age     int64
# dtype: object

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=4, step=1),
#  Index(['id', 'name', 'age'], dtype='str')]
