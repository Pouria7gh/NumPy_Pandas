# %%
import numpy as np
import pandas as pd

# %%
checklist = pd.Series(
    ['COMPLETE', np.nan, np.nan, np.nan, 'COMPLETE']
)
checklist
# Out:
# 0    COMPLETE
# 1         NaN
# 2         NaN
# 3         NaN
# 4    COMPLETE
# dtype: str

# %%
checklist.dropna()
# Out:
# 0    COMPLETE
# 4    COMPLETE
# dtype: str

# %%
checklist.dropna().reset_index(drop=True)
# Out:
# 0    COMPLETE
# 1    COMPLETE
# dtype: str

# %%
checklist.fillna('INCOMPLETE')
# Out:
# 0      COMPLETE
# 1    INCOMPLETE
# 2    INCOMPLETE
# 3    INCOMPLETE
# 4      COMPLETE
# dtype: str

# %%
my_series = pd.Series([np.nan] * 5)
my_series
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# dtype: float64

# %%
my_series.isna()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %%
my_series.isna().sum()
# Out:
# np.int64(5)

# %%
my_series.isna().mean()
# Out:
# np.float64(1.0)

# %%
my_series.astype('int')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 my_series.astype('int')
#
# File d:\Projects\NumPy_Pandas\venv\Lib\site-packages\pandas\core\generic.py:6529, in NDFrame.astype(self, dtype, copy, errors)
#    6525             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6526
#    6527         else:
#    6528             # else, only a single dtype is given
# -> 6529             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6530             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6531             return res.__finalize__(self, method="astype")
#    6532
#
# File d:\Projects\NumPy_Pandas\venv\Lib\site-packages\pandas\core\internals\managers.py:627, in BaseBlockManager.astype(self, dtype, errors)
#     626 def astype(self, dtype, errors: str = "raise") -> Self:
# ...

# %%
my_series = pd.Series([pd.NA] * 5)
my_series
# Out:
# 0    <NA>
# 1    <NA>
# 2    <NA>
# 3    <NA>
# 4    <NA>
# dtype: object

# %%
my_series = my_series.astype('Int16')

# %%
my_series.isna()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %%
my_series.value_counts(dropna=False)
# Out:
# <NA>    5
# Name: count, dtype: Int64

# %%
my_series = pd.Series(range(5))
my_series
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
my_series.iloc[1:3] = pd.NA
my_series
# Out:
# 0    0.0
# 1    NaN
# 2    NaN
# 3    3.0
# 4    4.0
# dtype: float64

# %%
my_series.isna()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
my_series.isna().mean() * 100
# Out:
# np.float64(40.0)

# %%
my_series.fillna(my_series.mean())
# Out:
# 0    0.000000
# 1    2.333333
# 2    2.333333
# 3    3.000000
# 4    4.000000
# dtype: float64

# %%
my_series.dropna()
# Out:
# 0    0.0
# 3    3.0
# 4    4.0
# dtype: float64

# %%
my_series.dropna().reset_index(drop=True)
# Out:
# 0    0.0
# 1    3.0
# 2    4.0
# dtype: float64
