# %%
import numpy as np
import pandas as pd

# %%
sales_series = pd.Series(
    [0, 5, 155, None, 518],
    index=['coffee', 'coffee', 'tea', 'coconut', 'sugar'],
    name='Sales',
    dtype='float'
)
sales_series
# Out:
# coffee       0.0
# coffee       5.0
# tea        155.0
# coconut      NaN
# sugar      518.0
# Name: Sales, dtype: float64

# %%
sales_series.sum()
# Out:
# np.float64(678.0)

# %%
sales_series.loc['coffee'].sum()
# Out:
# np.float64(5.0)

# %%
sales_series.quantile([0.25, 0.5, 0.75])
# Out:
# 0.25      3.75
# 0.50     80.00
# 0.75    245.75
# Name: Sales, dtype: float64

# %%
transactions = pd.read_csv('./assets/transactions.csv')
transactions_series = pd.Series(transactions.loc[:,'transactions'])
transactions_series.loc[:5]
# Out:
# 0     770
# 1    2111
# 2    2358
# 3    3487
# 4    1922
# 5    1903
# Name: transactions, dtype: int64

# %%
transactions_series.count()
# Out:
# np.int64(83488)

# %%
transactions_series.sum()
# Out:
# np.int64(141478945)

# %%
transactions_series.quantile([.5], interpolation='nearest')
# Out:
# 0.5    1393
# Name: transactions, dtype: int64

# %%
transactions_series.std()
# Out:
# np.float64(963.2866435167257)

# %%
transactions_series.var()
# Out:
# np.float64(927921.1575777193)
