# %%
import pandas as pd
import numpy as np

# %%
monday_sales = pd.Series([0, 5, 155, 0, 518])
monday_sales
# Out:
# 0      0
# 1      5
# 2    155
# 3      0
# 4    518
# dtype: int64

# %%
monday_sales + 2
# Out:
# 0      2
# 1      7
# 2    157
# 3      2
# 4    520
# dtype: int64

# %%
monday_sales.add(2)
# Out:
# 0      2
# 1      7
# 2    157
# 3      2
# 4    520
# dtype: int64

# %%
'$' + monday_sales.astype('float').astype('string')
# Out:
# 0      $0.0
# 1      $5.0
# 2    $155.0
# 3      $0.0
# 4    $518.0
# dtype: string

# %%
my_series = pd.Series(
    [1, np.nan, 2, 3, 4],
    index=['day 0', 'day 1', 'day 2', 'day 3', 'day 4']
)
my_series
# Out:
# day 0    1.0
# day 1    NaN
# day 2    2.0
# day 3    3.0
# day 4    4.0
# dtype: float64

# %%
my_series + 1
# Out:
# day 0    2.0
# day 1    NaN
# day 2    3.0
# day 3    4.0
# day 4    5.0
# dtype: float64

# %%
my_series2 = my_series.add(1, fill_value=0).astype('int')
my_series2
# Out:
# day 0    2
# day 1    1
# day 2    3
# day 3    4
# day 4    5
# dtype: int64

# %%
my_series2 / 2
# Out:
# day 0    1.0
# day 1    0.5
# day 2    1.5
# day 3    2.0
# day 4    2.5
# dtype: float64

# %%
my_series2 * 2
# Out:
# day 0     4
# day 1     2
# day 2     6
# day 3     8
# day 4    10
# dtype: int64

# %%
my_series2 // 2
# Out:
# day 0    1
# day 1    0
# day 2    1
# day 3    2
# day 4    2
# dtype: int64

# %%
my_series + my_series2
# Out:
# day 0    3.0
# day 1    NaN
# day 2    5.0
# day 3    7.0
# day 4    9.0
# dtype: float64

# %%
my_series2.add(my_series, fill_value=0).astype('int')
# Out:
# day 0    3
# day 1    1
# day 2    5
# day 3    7
# day 4    9
# dtype: int64
