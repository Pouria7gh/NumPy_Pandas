# %%
import numpy as np
import pandas as pd

# %%
checklist = pd.Series(
    ['COMPLETE', np.nan, np.nan, np.nan, 'COMPLETE']
)
checklist
# Out:
# 0    COMPLETE
# 1         NaN
# 2         NaN
# 3         NaN
# 4    COMPLETE
# dtype: str

# %%
checklist.isna()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
checklist[~checklist.isna()]
# Out:
# 0    COMPLETE
# 4    COMPLETE
# dtype: str

# %%
checklist.isna().sum()
# Out:
# np.int64(3)

# %%
checklist.value_counts()
# Out:
# COMPLETE    2
# Name: count, dtype: int64

# %%
checklist.value_counts(dropna=False)
# Out:
# NaN         3
# COMPLETE    2
# Name: count, dtype: int64
