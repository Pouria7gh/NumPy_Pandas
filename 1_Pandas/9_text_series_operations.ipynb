# %%
import numpy as np
import pandas as pd

# %%
prices = pd.Series(
    ['$3.99', '$5.99', '$22.99', '$7.99', '$33.99']
)
prices
# Out:
# 0     $3.99
# 1     $5.99
# 2    $22.99
# 3     $7.99
# 4    $33.99
# dtype: str

# %%
prices.str.contains('3')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
clean = prices.str.strip('$').astype('float')
clean
# Out:
# 0     3.99
# 1     5.99
# 2    22.99
# 3     7.99
# 4    33.99
# dtype: float64

# %%
string_series = pd.Series(['day 0', 'day 1', 'day 2', 'day 3', 'day 4'])
string_series
# Out:
# 0    day 0
# 1    day 1
# 2    day 2
# 3    day 3
# 4    day 4
# dtype: str

# %%
string_series.str.contains('D', case=False)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %%
string_series.str.contains('3')
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
string_series.str.upper().str.contains('day')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
string_series.str.strip('day ').astype('int')
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
string_series.str[-1].astype('int')
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
string_series.str[2:4]
# Out:
# 0    y
# 1    y
# 2    y
# 3    y
# 4    y
# dtype: str

# %%
string_series.str.split(' ', expand=True)
# Out:
#      0  1
# 0  day  0
# 1  day  1
# 2  day  2
# 3  day  3
# 4  day  4
