# %%
import numpy as np
import pandas as pd

# %%
retail_df = pd.read_csv('./assets/retail.csv')

# %%
retail_df.loc[:, ['sales', 'onpromotion']].sample(100).mean().round(2)
# Out:
# sales          478.91
# onpromotion      4.54
# dtype: float64

# %%
retail_df.loc[:, ['sales', 'onpromotion']].sample(100).mean().round(2)
# Out:
# sales          264.62
# onpromotion      4.12
# dtype: float64

# %%
primier_league = pd.read_csv('./assets/premier_league_games.csv')
primier_league['season'].max()
# Out:
# np.int64(9900)

# %%
primier_league.sum()
# Out:
# id                                                      80702160
# league_name    Premier LeaguePremier LeaguePremier LeaguePrem...
# season                                                  39788298
# home_team      ArsenalAston VillaChelseaLiverpoolMan CityNewc...
# away_team      CoventryQPRBlackburnSheffield WedsLeedsTottenh...
# home_goals                                                 19448
# away_goals                                                 14808
# dtype: object

# %%
primier_league.loc[:, ['home_goals', 'away_goals']].mean()
# Out:
# home_goals    1.530856
# away_goals    1.165617
# dtype: float64

# %%
primier_league.loc[:, ['home_goals', 'away_goals']].std()
# Out:
# home_goals    1.303925
# away_goals    1.145536
# dtype: float64
